# %% [markdown]
# # Visualization

# %%
import pandas as pd

df = pd.read_csv('../data/titanic_clean_data.csv')

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex  Age  Parch     Fare  Embarked  NameLength  HasCabin  \
# 0         0       3    1   22      0   7.2500         0          23         0
# 1         1       1    0   38      0  71.2833         1          51         1
# 2         1       3    0   26      0   7.9250         0          22         0
#
#    FamilySize  IsAlone  CategoricalFare  CategoricalAge  Title
# 0           2        0                0               1      3
# 1           2        0                3               3      2
# 2           1        1                1               2      4

# %%
    # Mapping Embarked
    df['Embarked'] = df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex  Age  Parch     Fare  Embarked  NameLength  HasCabin  \
# 0         0       3    1   22      0   7.2500         0          23         0
# 1         1       1    0   38      0  71.2833         1          51         1
# 2         1       3    0   26      0   7.9250         0          22         0
#
#    FamilySize  IsAlone  CategoricalFare  CategoricalAge  Title
# 0           2        0                0               1      3
# 1           2        0                3               3      2
# 2           1        1                1               2      4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

colormap = plt.cm.Blues
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df.astype(float).corr().abs(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %%
g = sns.pairplot(df[[u'Survived', u'Pclass', u'Sex', u'Age', u'Parch', u'Fare', u'Embarked',
       u'FamilySize', u'Title']], hue='Survived', palette = 'seismic',size=1.2,diag_kind = 'kde',diag_kws=dict(shade=True),plot_kws=dict(s=10) )
g.set(xticklabels=[])
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked',
#        'NameLength', 'HasCabin', 'FamilySize', 'IsAlone', 'CategoricalFare',
#        'CategoricalAge', 'Title'],
#       dtype='object')

# %%
def rgb(r, g, b):
    return r/255, g/255, b/255

# %%
colors = [rgb(141, 198, 227),rgb(61, 156, 209)]
features = ['Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'Title', 'IsAlone']

fig, axes = plt.subplots(nrows = 3,ncols = 3,figsize = (15,12))
for i, item in enumerate(features):
    if i < 3:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i,0],rot = 0, color=colors)
        
    elif i >=3 and i < 6:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-3,1],rot = 0, color=colors)
        
    elif i < 9:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-6,2],rot = 0, color=colors)
    ax.set_title(item)

# %%
df['CategoricalAge'].value_counts().plot(kind = 'bar', rot = 0, color=colors)
# Out:
# <AxesSubplot:>
